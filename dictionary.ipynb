# %% [markdown]
# ### creating a dictionary

# %%
thisdict={
    "name":"sajiya",
    "age":28,
    "major":"business analytics"
}
print(thisdict)
# Out:
# {'name': 'sajiya', 'age': 28, 'major': 'business analytics'}
