# %% [markdown]
# ###list in python

# %%
list1=["apple","banana","grapes"]
list1
# Out:
# ['apple', 'banana', 'grapes']

# %%
list1=["apple","banana","grapes"]
print(list1)
# Out:
# ['apple', 'banana', 'grapes']

# %% [markdown]
# ### how to create a list in python

# %%
list2=["lion","tiger","giraffe"]
list2
# Out:
# ['lion', 'tiger', 'giraffe']

# %% [markdown]
# ### change item value of the list

# %%
list=["apple","banana","cherry"]
print(list)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist=["apple", "banana", "cherry"]
thislist[1]= "blackcurrent"
print(thislist)

# %% [markdown]
# ### append function

# %%
list1=["apple","banana","cherry"]
list1.append("orange")
list1
# Out:
# ['apple', 'banana', 'cherry', 'orange']
