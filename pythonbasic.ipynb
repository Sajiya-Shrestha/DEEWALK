# %%
print("hello world")
#for printing the string we have to use a double quotes
# Out:
# hello world

# %% [markdown]
# ###python indentation

# %%
if 5>2:
 print("this is code")
# Out:
# this is code

# %%
if 5>2:
 print("this is code")
# Out:
# this is code

# %% [markdown]
# print()=this is a defult python function used to print the text or logic on the screen

# %% [markdown]
# ### i am learning python

# %%
V=" sajiya "
V.strip()
# Out:
# 'sajiya'

# %%
variable_name=" fjhgjhkhjkhnkjikjk "
variable_name.strip()
# Out:
# 'fjhgjhkhjkhnkjikjk'

# %%
a="sajiya"
a.upper()
# Out:
# 'SAJIYA'

# %%
a="hello"
a.replace("h","j")
# Out:
# 'jello'

# %%
variable="hhhhhhjjjjklinh"
variable.replace("h","o")
# Out:
# 'oooooojjjjklino'

# %%
x= "orange"
y= "apple"
z= "cherry"
print(x)
print(y)
print(z)
# Out:
# orange
# apple
# cherry

# %%
print(x,y,z)
# Out:
# orange apple cherry

# %%
print("hello, world")
# Out:
# hello, world

# %%
x= "sajiya"
y= "is"
z= "awsome"
print(x+ y+ z)
# Out:
# sajiyaisawsome

# %%
a="jiya"
a= "JIYA"
print(a)
# Out:
# JIYA

# %%
fruits= ["apple", "banana", "cherry"]
x,y,z= fruits
print(z)
# Out:
# cherry

# %%
### list is mutable and tuple is immutable

# %%
x=int(1)
y=int(2.5)
z=int("3")
print(x,y,z)
# Out:
# 1 2 3

# %%
num1=input("enter the first number")
num2=input("enter the second number")
num1+num2

# %%
num1=int(input("enter the first number"))
num2=int(input("enter the second number"))
num1+num2

# %%
num1 = 5

num2 = 3
num1=int(input("enter the first number"))
num2=int(input("enter the second number"))
num1+num2

# %%
x=float(1)
print(x)
