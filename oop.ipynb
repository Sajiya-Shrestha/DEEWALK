# %%
class animal:
    x=5
p1=animal()
print(p1.x)
# Out:
# 5

# %% [markdown]
# ### we re learning constructor in python

# %%
class person:
    def_init_(self,name,age):
    self.n=name
    self.a=age
    
    p=person("sajiya",28)
# Out:
#   Cell In[8], line 2
#     def_init_(self,name,age):
#                             ^
# SyntaxError: invalid syntax

# %% [markdown]
# # we are doing parent child class

# %%
class parent:
 def show(self):
  print("i am parent class")

  class child(parent):
   df show(self):
   print("hello i am a child class")

   a=child()
   a.show()
   a.display()
# Out:
#   Cell In[4], line 6
#     df show(self):
#        ^
# SyntaxError: invalid syntax

# %%
class father:
 def display (self):
     print("hello i am a father")

class mother:
    def show(self):
        print("hello i am a mother")

class child(father,mother):
    pass

c1=child()
c1.show()
# Out:
# hello i am a mother
